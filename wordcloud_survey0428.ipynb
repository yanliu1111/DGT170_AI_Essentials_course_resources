# %% [markdown]
# <a href="https://colab.research.google.com/github/yanliu1111/DGT170_AI_Essentials_course_resources/blob/main/wordcloud_survey0428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Book0428.csv')
data.head()
# Out:
#      ID        Start time   Completion time      Email  Name  Total points  \
# 0  2166  4/26/25 10:05:45  4/26/25 10:08:07  anonymous   NaN           NaN
# 1  2167   4/26/25 8:37:25  4/26/25 12:06:35  anonymous   NaN           NaN
# 2  2168  4/28/25 16:37:08  4/28/25 16:37:58  anonymous   NaN           NaN
# 3  2169  4/28/25 16:37:12  4/28/25 16:38:10  anonymous   NaN           NaN
# 4  2170  4/28/25 16:37:11  4/28/25 16:38:11  anonymous   NaN           NaN
#
#    Quiz feedback  Enter your age  Points - Enter your age  \
# 0            NaN              45                      NaN
# 1            NaN              46                      NaN
# 2            NaN              30                      NaN
# 3            NaN              37                      NaN
# 4            NaN              36                      NaN
#
#    Feedback - Enter your age  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
#
#   Feedback - Do you have any experience with programming languages or tools used in AI? (e.g. Python)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    What motivated you to take this course? (Please select all that apply)  \
# 0                      Personal growth and learning;
# 1                     Interest in AI and technology;
# 2  Free course availability;Personal growth and l...
# 3  Free course availability;Personal growth and l...
# 4                     Interest in AI and technology;
#
#    Points - What motivated you to take this course? (Please select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Feedback - What motivated you to take this course? (Please select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    What are your goals for completing this course? (Please select all that apply)  \
# 0                 Gain a better understanding of AI;
# 1                   Enhance my current skills in AI;
# 2  Gain a better understanding of AI;Improve my j...
# 3  Gain a better understanding of AI;Improve my j...
# 4                 Gain a better understanding of AI;
#
#    Points - What are your goals for completing this course? (Please select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Feedback - What are your goals for completing this course? (Please select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    What specific AI topics or skills are you most interested in learning about?  \
# 0  How to maximize the use of AI as tools/assista...
# 1                                     copilt,  azure
# 2         Interested in leveraging AI in healthcare.
# 3              Gen AI, LLM and MCPs, Test Automation
# 4                           General use of the tools
#
#    Points - What specific AI topics or skills are you most interested in learning about?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Feedback - What specific AI topics or skills are you most interested in learning about?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 43 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd

# Assuming 'data' is your DataFrame
text = data['Which city are you currently located in?'].values

# Clean the text data
cleaned_text = []
for city in text:
    cleaned_city = str(city).replace("'", "").replace(" ", "").lower()
    cleaned_text.append(cleaned_city)

# Join the cleaned words into a single string
text_for_wordcloud = " ".join(cleaned_text)

wordcloud = WordCloud(
    width=1600,
    height=800,
    background_color='black',
).generate(text_for_wordcloud)

fig = plt.figure(
    figsize=(20, 5),
    facecolor='k',
    edgecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = data['What motivated you to take this course? (Please select all that apply)'].values
wordcloud = WordCloud(
    width = 1600,
    height = 800,
    background_color = 'black',
).generate(str(text))
fig = plt.figure(
    figsize = (20, 5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
