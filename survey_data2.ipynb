# %% [markdown]
# <a href="https://colab.research.google.com/github/yanliu1111/DGT170_AI_Essentials_course_resources/blob/main/survey_data2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas and matplotlib for data analysis and visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Enable inline plotting for Jupyter notebooks
# %matplotlib inline

# %% [markdown]
# # Load the Dataset
# Load the dataset from the specified file path using pandas.

# %%
# Load the Dataset

# Load the dataset from the specified file path using pandas
file_path = '/content/surveydata2.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe to verify it loaded correctly
df.head()
# Out:
#    Enter your age  Gender Which city are you currently located in?  \
# 0              42  Female                                Carstairs
# 1              53  Female                                  Calgary
# 2              43    Male                           Barrie Ontario
# 3              36    Male                                  Calgary
# 4              29  Female                                  Calgary
#
#   Country of Residence What is your level of education?  \
# 0               Canada                Bachelor's Degree
# 1               Canada                  Master's Degree
# 2               Canada                           Others
# 3               Canada                Bachelor's Degree
# 4               Canada                Bachelor's Degree
#
#   Are you currently affiliated with the University of Calgary? (Please select the option that best describes your affiliation.)  \
# 0                                              Staff
# 1                                             Alumni
# 2                       Continuing Education student
# 3                                             Alumni
# 4                                             Alumni
#
#   How would you rate your experience with Artificial Intelligence (AI)  \
# 0                                           Beginner
# 1                                           Beginner
# 2                                       Intermediate
# 3                                           Beginner
# 4                                           Beginner
#
#   What motivated you to take this course? (Please select all that apply)  \
# 0  Interest in AI and technology;Career advancement;
# 1  Career advancement;Personal growth and learnin...
# 2  Interest in AI and technology;Free course avai...
# 3  Career advancement;Personal growth and learnin...
# 4  Free course availability;Interest in AI and te...
#
#   What are your goals for completing this course? (Please select all that apply)  \
# 0  Gain a better understanding of AI;Enhance my c...
# 1  Gain a better understanding of AI;Enhance my c...
# 2  Gain a better understanding of AI;Enhance my c...
# 3  Gain a better understanding of AI;Improve my j...
# 4  Gain a better understanding of AI;Improve my j...
#
#   What specific AI topics or skills are you most interested in learning about?
# 0   How to embed it in the work place, pros and cons
# 1  Just how to stay up to date with developments ...
# 2  Opportunities in Microsoft 365/Azure for Gener...
# 3           Learning how to use AI beyond the basics
# 4

# %% [markdown]
# # Display Basic Information
# Display the first few rows, summary statistics, and information about the dataset to understand its structure.

# %%
# Display the first few rows of the dataframe to verify it loaded correctly
df.head()

# Display summary statistics of the dataset
df.describe(include='all')

# Display information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 10 columns):
#  #   Column                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                         --------------  -----
#  0   Enter your age                                                                                                                 322 non-null    int64
#  1   Gender                                                                                                                         322 non-null    object
#  2   Which city are you currently located in?                                                                                       322 non-null    object
#  3   Country of Residence                                                                                                           322 non-null    object
#  4   What is your level of education?                                                                                               322 non-null    object
#  5   Are you currently affiliated with the University of Calgary? (Please select the option that best describes your affiliation.)  322 non-null    object
#  6   How would you rate your experience with Artificial Intelligence (AI)                                                           322 non-null    object
#  7   What motivated you to take this course? (Please select all that apply)                                                         322 non-null    object
#  8   What are your goals for completing this course? (Please select all that apply)                                                 322 non-null    object
#  9   What specific AI topics or skills are you most interested in learning about?                                                   316 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 25.3+ KB

# %% [markdown]
# # Demographic Analysis
# Analyze the demographics of the survey respondents, including age, gender, location, education level, and University of Calgary affiliation.

# %%
# Demographic Analysis

# Analyze the age distribution of the survey respondents
plt.figure(figsize=(10, 6))
df['Enter your age'].hist(bins=20, edgecolor='black')
plt.title('Age Distribution of Survey Respondents')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# Analyze the gender distribution of the survey respondents
plt.figure(figsize=(10, 6))
df['Gender'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Gender Distribution of Survey Respondents')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# Analyze the location distribution of the survey respondents
plt.figure(figsize=(10, 6))
df['Which city are you currently located in?'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Location Distribution of Survey Respondents')
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# Analyze the education level of the survey respondents
plt.figure(figsize=(10, 6))
df['What is your level of education?'].value_counts().plot(kind='bar', color='lightcoral', edgecolor='black')
plt.title('Education Level of Survey Respondents')
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# Analyze the University of Calgary affiliation of the survey respondents
plt.figure(figsize=(10, 6))
df['Are you currently affiliated with the University of Calgary? (Please select the option that best describes your affiliation.)'].value_counts().plot(kind='bar', color='lightblue', edgecolor='black')
plt.title('University of Calgary Affiliation of Survey Respondents')
plt.xlabel('Affiliation')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# # Specific AI Topics of Interest
# Explore and visualize the specific AI topics of interest to the survey respondents.

# %%
# Specific AI Topics of Interest

# Analyze the specific AI topics of interest to the survey respondents
# Display the count of each AI topic category
ai_topics_counts = df['What are your goals for completing this course? (Please select all that apply)'].value_counts()
print(ai_topics_counts)

# Plot the AI topics distribution as a pie chart
plt.figure(figsize=(10, 6))
ai_topics_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightpink'])
plt.title('Specific AI Topics of Interest Distribution')
plt.ylabel('')
plt.show()

# Display the count of each AI topic category
ai_topics_counts = df['What motivated you to take this course? (Please select all that apply)'].value_counts()
print(ai_topics_counts)

# Plot the AI topics distribution as a pie chart
plt.figure(figsize=(10, 6))
ai_topics_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightpink'])
plt.title('Specific AI Topics of Interest Distribution')
plt.ylabel('')
plt.show()
# Out:
# What are your goals for completing this course? (Please select all that apply)
# Gain a better understanding of AI;Enhance my current skills in AI;                                                                103
# Gain a better understanding of AI;                                                                                                 67
# Gain a better understanding of AI;Improve my job prospects;Enhance my current skills in AI;Transition into a new career field;     34
# Gain a better understanding of AI;Improve my job prospects;Enhance my current skills in AI;                                        33
# Enhance my current skills in AI;                                                                                                   23
# Gain a better understanding of AI;Improve my job prospects;                                                                        13
# Gain a better understanding of AI;Enhance my current skills in AI;Improve my job prospects;                                         9
# Enhance my current skills in AI;Gain a better understanding of AI;                                                                  7
# Improve my job prospects;                                                                                                           6
# Gain a better understanding of AI;Improve my job prospects;Transition into a new career field;                                      4
# Gain a better understanding of AI;Transition into a new career field;                                                               4
# Gain a better understanding of AI;Enhance my current skills in AI;Transition into a new career field;                               4
# Improve my job prospects;Enhance my current skills in AI;                                                                           3
# Gain a better understanding of AI;Improve my job prospects;Transition into a new career field;Enhance my current skills in AI;      2
# Improve my job prospects;Gain a better understanding of AI;                                                                         2
# Enhance my current skills in AI;Gain a better understanding of AI;Transition into a new career field;Improve my job prospects;      1
# Transition into a new career field;Enhance my current skills in AI;                                                                 1
# Improve my job prospects;Transition into a new career field;Enhance my current skills in AI;                                        1
# Enhance my current skills in AI;Improve my job prospects;Gain a better understanding of AI;Transition into a new career field;      1
# Improve my job prospects;Enhance my current skills in AI;Transition into a new career field;Gain a better understanding of AI;      1
# Transition into a new career field;                                                                                                 1
# Improve my job prospects;Enhance my current skills in AI;Gain a better understanding of AI;Transition into a new career field;      1
# Enhance my current skills in AI;Transition into a new career field;                                                                 1
# Name: count, dtype: int64
# What motivated you to take this course? (Please select all that apply)
# Interest in AI and technology;                                                                                                        35
# Personal growth and learning;                                                                                                         27
# Interest in AI and technology;Personal growth and learning;                                                                           13
# Personal growth and learning;Free course availability;Interest in AI and technology;                                                  13
# Personal growth and learning;Interest in AI and technology;                                                                           12
#                                                                                                                                       ..
# Career advancement;Free course availability;Interest in AI and technology;Personal growth and learning;Recommendation from others;     1
# Personal growth and learning;Recommendation from others;                                                                               1
# Career advancement;Interest in AI and technology;Recommendation from others;Free course availability;Personal growth and learning;     1
# Free course availability;Interest in AI and technology;Career advancement;Personal growth and learning;                                1
# Career advancement;Personal growth and learning;Recommendation from others;Free course availability;Interest in AI and technology;     1
# Name: count, Length: 90, dtype: int64
